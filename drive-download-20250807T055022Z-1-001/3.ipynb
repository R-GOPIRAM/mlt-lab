# %%
import pandas as pd
import numpy as np
import statistics as st

# Correct URL for the dataset
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"

# Load dataset with appropriate column names
columns = ['preg', 'plas', 'pres', 'skin', 'insu', 'mass', 'pedi', 'age', 'class']
df = pd.read_csv(url, names=columns)

# Print shape and info
print(df.shape[0])  # Number of rows
print(len(df.columns))  # Number of columns
print(df.columns.tolist())  # Column names

# Correlation of all columns with 'plas'
correlation_with_plas = df.corr(numeric_only=True)['plas']
print(correlation_with_plas)

# Optional interpretation
print("correlation below 1")
print(correlation_with_plas.drop('plas'))  # Exclude self-correlation (plas-plas = 1.0)
# Out:
# 768
# 9
# ['preg', 'plas', 'pres', 'skin', 'insu', 'mass', 'pedi', 'age', 'class']
# preg     0.129459
# plas     1.000000
# pres     0.152590
# skin     0.057328
# insu     0.331357
# mass     0.221071
# pedi     0.137337
# age      0.263514
# class    0.466581
# Name: plas, dtype: float64
# correlation below 1
# preg     0.129459
# pres     0.152590
# skin     0.057328
# insu     0.331357
# mass     0.221071
# pedi     0.137337
# age      0.263514
# class    0.466581
# Name: plas, dtype: float64

# %%
# Import statistics library
import statistics

# Calculate average values
print(statistics.mean([1, 3, 5, 7, 9, 11, 13]))
print(statistics.mean([1, 3, 5, 7, 9, 11]))
print(statistics.mean([-11, 5.5, -3.4, 7.1, -9, 22]))

# Calculate middle values
print(statistics.median([1, 3, 5, 7, 9, 11, 13]))
print(statistics.median([1, 3, 5, 7, 9, 11]))
print(statistics.median([-11, 5.5, -3.4, 7.1, -9, 22]))
# Out:
# 7
# 6
# 1.8666666666666667
# 7
# 6.0
# 1.05

# %%
# Import statistics library
import statistics

# Calculate the mode
print(statistics.mode([1, 1, 3, 3, 3, 5, 7, 7, 9, 11]))
print(statistics.mode([1, 3, 3, -5, 7, -9, -11]))
print(statistics.mode(['red', 'green', 'blue', 'red']))
# Out:
# 3
# 3
# red

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev([1, 3, 5, 7, 9, 11]))
print(statistics.stdev([2, 2.5, 1.25, 3.1, 1.75, 2.8]))
print(statistics.stdev([-11, 5.5, -3.4, 7.1]))
print(statistics.stdev([1, 30, 50, 100]))
# Out:
# 3.7416573867739413
# 0.6925797186365383
# 8.414471660973927
# 41.67633221226007
# 14
# 0.47966666666666663
# 70.80333333333333
# 1736.9166666666667

# %%
# Import statistics Library
import statistics

# Calculate the variance from a sample of data
print(statistics.variance([1, 3, 5, 7, 9, 11]))
print(statistics.variance([2, 2.5, 1.25, 3.1, 1.75, 2.8]))
print(statistics.variance([-11, 5.5, -3.4, 7.1]))
print(statistics.variance([1, 30, 50, 100]))
# Out:
# 14
# 0.47966666666666663
# 70.80333333333333
# 1736.9166666666667
